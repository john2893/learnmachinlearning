# %%
from pandas import read_csv

# %%
import pandas as pd

# %%
df = pd.read_csv("sales.csv")
# Out:
# /home/johns/.local/lib/python3.6/site-packages/IPython/core/interactiveshell.py:3072: DtypeWarning: Columns (0) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
df
# Out:
#          order_id  order_date      status   item_id                    sku  \
# 0       100354678  2020-10-01    received  574772.0     oasis_Oasis-064-36
# 1       100354678  2020-10-01    received  574774.0        Fantastic_FT-48
# 2       100354680  2020-10-01    complete  574777.0        mdeal_DMC-610-8
# 3       100354680  2020-10-01    complete  574779.0     oasis_Oasis-061-36
# 4       100367357  2020-11-13    received  595185.0    MEFNAR59C38B6CA08CD
# ...           ...         ...         ...       ...                    ...
# 286387  100562365  2021-09-30        paid  905179.0    APPCHA5AF14939B8F8A
# 286388  100562376  2021-09-30         cod  905191.0    MEFCOT5A8D1E973B886
# 286389  100562383  2021-09-30         cod  905200.0  WOFVAL59D5EA84167F9-M
# 286390  100562384  2021-09-30         cod  905202.0  WOFNIG5B4D7EB0E9FDD-L
# 286391  100562386  2021-09-30  processing  905205.0    MATHUA5AF70A7D1E50A
#
#         qty_ordered   price   value  discount_amount   total  ...  \
# ...

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df.dtypes
# Out:
# order_id             object
# order_date           object
# status               object
# item_id             float64
# sku                  object
# qty_ordered         float64
# price               float64
# value               float64
# discount_amount     float64
# total               float64
# category             object
# payment_method       object
# bi_st                object
# cust_id             float64
# year                  int64
# month                object
# ref_num               int64
# Name Prefix          object
# First Name           object
# Middle Initial       object
# Last Name            object
# Gender               object
# age                 float64
# full_name            object
# E Mail               object
# Customer Since       object
# SSN                  object
# Phone No.            object
# Place Name           object
# County               object
# City                 object
# State                object
# Zip                   int64
# ...

# %%
df
# Out:
#          order_id  order_date      status   item_id                    sku  \
# 0       100354678  2020-10-01    received  574772.0     oasis_Oasis-064-36
# 1       100354678  2020-10-01    received  574774.0        Fantastic_FT-48
# 2       100354680  2020-10-01    complete  574777.0        mdeal_DMC-610-8
# 3       100354680  2020-10-01    complete  574779.0     oasis_Oasis-061-36
# 4       100367357  2020-11-13    received  595185.0    MEFNAR59C38B6CA08CD
# ...           ...         ...         ...       ...                    ...
# 286387  100562365  2021-09-30        paid  905179.0    APPCHA5AF14939B8F8A
# 286388  100562376  2021-09-30         cod  905191.0    MEFCOT5A8D1E973B886
# 286389  100562383  2021-09-30         cod  905200.0  WOFVAL59D5EA84167F9-M
# 286390  100562384  2021-09-30         cod  905202.0  WOFNIG5B4D7EB0E9FDD-L
# 286391  100562386  2021-09-30  processing  905205.0    MATHUA5AF70A7D1E50A
#
#         qty_ordered   price   value  discount_amount   total  ...  \
# ...

# %%
 df.head()
# Out:
#     order_id  order_date    status   item_id                  sku  \
# 0  100354678  2020-10-01  received  574772.0   oasis_Oasis-064-36
# 1  100354678  2020-10-01  received  574774.0      Fantastic_FT-48
# 2  100354680  2020-10-01  complete  574777.0      mdeal_DMC-610-8
# 3  100354680  2020-10-01  complete  574779.0   oasis_Oasis-061-36
# 4  100367357  2020-11-13  received  595185.0  MEFNAR59C38B6CA08CD
#
#    qty_ordered  price   value  discount_amount   total  ...          SSN  \
# 0         21.0   89.9  1798.0              0.0  1798.0  ...  627-31-5251
# 1         11.0   19.0   190.0              0.0   190.0  ...  627-31-5251
# 2          9.0  149.9  1199.2              0.0  1199.2  ...  627-31-5251
# 3          9.0   79.9   639.2              0.0   639.2  ...  627-31-5251
# 4          2.0   99.9    99.9              0.0    99.9  ...  627-31-5251
#
#      Phone No.  Place Name  County    City State    Zip Region User Name  \
# ...

# %%
df.shape
# Out:
# (286392, 36)

# %%
df.tail()
# Out:
#          order_id  order_date      status   item_id                    sku  \
# 286387  100562365  2021-09-30        paid  905179.0    APPCHA5AF14939B8F8A
# 286388  100562376  2021-09-30         cod  905191.0    MEFCOT5A8D1E973B886
# 286389  100562383  2021-09-30         cod  905200.0  WOFVAL59D5EA84167F9-M
# 286390  100562384  2021-09-30         cod  905202.0  WOFNIG5B4D7EB0E9FDD-L
# 286391  100562386  2021-09-30  processing  905205.0    MATHUA5AF70A7D1E50A
#
#         qty_ordered   price   value  discount_amount   total  ...  \
# 286387          2.0  4419.9  4419.9              0.0  4419.9  ...
# 286388          2.0    39.9    39.9              0.0    39.9  ...
# 286389          2.0    40.0    40.0              0.0    40.0  ...
# 286390          2.0    49.9    49.9              0.0    49.9  ...
# 286391          2.0  3559.9  3559.9              0.0  3559.9  ...
#
#                 SSN    Phone No.      Place Name    County           City  \
# ...

# %%
temp = pd.DataFrame({"A":["1","2","3"], "B":[11,12,13], "C": ["12-06-2012", "13-06-2015", "15-06-2017"]})

# %%
temp.dtypes
# Out:
# A    object
# B     int64
# C    object
# dtype: object

# %%
pd.to_datetime("2016-jun-02")
# Out:
# Timestamp('2016-06-02 00:00:00')

# %%
temp
# Out:
#    A   B           C
# 0  1  11  12-06-2012
# 1  2  12  13-06-2015
# 2  3  13  15-06-2017

# %%
temp["C"] = pd.to_datetime(temp["C"])

# %%
temp
# Out:
#    A   B          C
# 0  1  11 2012-12-06
# 1  2  12 2015-06-13
# 2  3  13 2017-06-15

# %%
temp.dtypes
# Out:
# A            object
# B             int64
# C    datetime64[ns]
# dtype: object

# %%
temp["A"] = pd.to_numeric(temp["A"])

# %%
temp.dtypes
# Out:
# A             int64
# B             int64
# C    datetime64[ns]
# dtype: object

# %%
df.describe()
# Out:
#              item_id    qty_ordered          price          value  \
# count  286392.000000  286392.000000  286392.000000  286392.000000
# mean   741664.902131       3.011296     851.385253     885.879934
# std     95746.031827       4.573837    1741.750751    2073.252179
# min    574769.000000       1.000000       0.000000       0.000000
# 25%    659684.500000       2.000000      49.900000      49.900000
# 50%    742309.000000       2.000000     119.000000     158.970000
# 75%    826124.250000       3.000000     950.000000     910.000000
# max    905208.000000     501.000000  101262.590000  101262.590000
#
#        discount_amount          total        cust_id           year  \
# count    286392.000000  286392.000000  286392.000000  286392.000000
# mean         70.039427     815.840507   70048.019054    2020.618778
# std         256.880870    1983.580302   30243.856395       0.485688
# min           0.000000       0.000000       4.000000    2020.000000
# ...

# %%
df
# Out:
#          order_id  order_date      status   item_id                    sku  \
# 0       100354678  2020-10-01    received  574772.0     oasis_Oasis-064-36
# 1       100354678  2020-10-01    received  574774.0        Fantastic_FT-48
# 2       100354680  2020-10-01    complete  574777.0        mdeal_DMC-610-8
# 3       100354680  2020-10-01    complete  574779.0     oasis_Oasis-061-36
# 4       100367357  2020-11-13    received  595185.0    MEFNAR59C38B6CA08CD
# ...           ...         ...         ...       ...                    ...
# 286387  100562365  2021-09-30        paid  905179.0    APPCHA5AF14939B8F8A
# 286388  100562376  2021-09-30         cod  905191.0    MEFCOT5A8D1E973B886
# 286389  100562383  2021-09-30         cod  905200.0  WOFVAL59D5EA84167F9-M
# 286390  100562384  2021-09-30         cod  905202.0  WOFNIG5B4D7EB0E9FDD-L
# 286391  100562386  2021-09-30  processing  905205.0    MATHUA5AF70A7D1E50A
#
#         qty_ordered   price   value  discount_amount   total  ...  \
# ...

# %%
df["sku"].value_counts().head()
# Out:
# MATSAM59DB75ADB2F80    3775
# MATSAM59DB757FB47A2    1273
# APPNAT5A0A01860CE92    1173
# MATSAM5A7463EE3C1A5    1171
# ENTECO5A7FE80D6C830    1023
# Name: sku, dtype: int64

# %%
df.iloc[0:5, 0:4]
# Out:
#     order_id  order_date    status   item_id
# 0  100354678  2020-10-01  received  574772.0
# 1  100354678  2020-10-01  received  574774.0
# 2  100354680  2020-10-01  complete  574777.0
# 3  100354680  2020-10-01  complete  574779.0
# 4  100367357  2020-11-13  received  595185.0

# %%
df.iloc[0:5, 0:4]
# Out:
#     order_id  order_date    status   item_id
# 0  100354678  2020-10-01  received  574772.0
# 1  100354678  2020-10-01  received  574774.0
# 2  100354680  2020-10-01  complete  574777.0
# 3  100354680  2020-10-01  complete  574779.0
# 4  100367357  2020-11-13  received  595185.0

# %%
df.iloc[:,0:4]
# Out:
#          order_id  order_date      status   item_id
# 0       100354678  2020-10-01    received  574772.0
# 1       100354678  2020-10-01    received  574774.0
# 2       100354680  2020-10-01    complete  574777.0
# 3       100354680  2020-10-01    complete  574779.0
# 4       100367357  2020-11-13    received  595185.0
# ...           ...         ...         ...       ...
# 286387  100562365  2021-09-30        paid  905179.0
# 286388  100562376  2021-09-30         cod  905191.0
# 286389  100562383  2021-09-30         cod  905200.0
# 286390  100562384  2021-09-30         cod  905202.0
# 286391  100562386  2021-09-30  processing  905205.0
#
# [286392 rows x 4 columns]

# %%
df.iloc[:,: -1]
# Out:
#          order_id  order_date      status   item_id                    sku  \
# 0       100354678  2020-10-01    received  574772.0     oasis_Oasis-064-36
# 1       100354678  2020-10-01    received  574774.0        Fantastic_FT-48
# 2       100354680  2020-10-01    complete  574777.0        mdeal_DMC-610-8
# 3       100354680  2020-10-01    complete  574779.0     oasis_Oasis-061-36
# 4       100367357  2020-11-13    received  595185.0    MEFNAR59C38B6CA08CD
# ...           ...         ...         ...       ...                    ...
# 286387  100562365  2021-09-30        paid  905179.0    APPCHA5AF14939B8F8A
# 286388  100562376  2021-09-30         cod  905191.0    MEFCOT5A8D1E973B886
# 286389  100562383  2021-09-30         cod  905200.0  WOFVAL59D5EA84167F9-M
# 286390  100562384  2021-09-30         cod  905202.0  WOFNIG5B4D7EB0E9FDD-L
# 286391  100562386  2021-09-30  processing  905205.0    MATHUA5AF70A7D1E50A
#
#         qty_ordered   price   value  discount_amount   total  ...  \
# ...

# %%
df.loc[:,["order_date", "status"]]
# Out:
#         order_date      status
# 0       2020-10-01    received
# 1       2020-10-01    received
# 2       2020-10-01    complete
# 3       2020-10-01    complete
# 4       2020-11-13    received
# ...            ...         ...
# 286387  2021-09-30        paid
# 286388  2021-09-30         cod
# 286389  2021-09-30         cod
# 286390  2021-09-30         cod
# 286391  2021-09-30  processing
#
# [286392 rows x 2 columns]

# %%
df.loc[:,["order_date"]]
# Out:
#         order_date
# 0       2020-10-01
# 1       2020-10-01
# 2       2020-10-01
# 3       2020-10-01
# 4       2020-11-13
# ...            ...
# 286387  2021-09-30
# 286388  2021-09-30
# 286389  2021-09-30
# 286390  2021-09-30
# 286391  2021-09-30
#
# [286392 rows x 1 columns]

# %%
df.iloc[0:6, 0:4]
# Out:
#     order_id  order_date    status   item_id
# 0  100354678  2020-10-01  received  574772.0
# 1  100354678  2020-10-01  received  574774.0
# 2  100354680  2020-10-01  complete  574777.0
# 3  100354680  2020-10-01  complete  574779.0
# 4  100367357  2020-11-13  received  595185.0
# 5  100367357  2020-11-13  received  595186.0

# %%
df.columns
# Out:
# Index(['order_id', 'order_date', 'status', 'item_id', 'sku', 'qty_ordered',
#        'price', 'value', 'discount_amount', 'total', 'category',
#        'payment_method', 'bi_st', 'cust_id', 'year', 'month', 'ref_num',
#        'Name Prefix', 'First Name', 'Middle Initial', 'Last Name', 'Gender',
#        'age', 'full_name', 'E Mail', 'Customer Since', 'SSN', 'Phone No. ',
#        'Place Name', 'County', 'City', 'State', 'Zip', 'Region', 'User Name',
#        'Discount_Percent'],
#       dtype='object')

# %%
df.iloc[0:6, [0,7]]
# Out:
#     order_id   value
# 0  100354678  1798.0
# 1  100354678   190.0
# 2  100354680  1199.2
# 3  100354680   639.2
# 4  100367357    99.9
# 5  100367357    39.9

# %%
df.iloc[0:6, [3,7]]
# Out:
#     item_id   value
# 0  574772.0  1798.0
# 1  574774.0   190.0
# 2  574777.0  1199.2
# 3  574779.0   639.2
# 4  595185.0    99.9
# 5  595186.0    39.9

# %%
df.loc[['City']]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-13-2df78ba56a2e> in <module>
# ----> 1 df.loc[['City']]
#
# ~/.local/lib/python3.6/site-packages/pandas/core/indexing.py in __getitem__(self, key)
#     877
#     878             maybe_callable = com.apply_if_callable(key, self.obj)
# --> 879             return self._getitem_axis(maybe_callable, axis=axis)
#     880
#     881     def _is_scalar_access(self, key: Tuple):
#
# ~/.local/lib/python3.6/site-packages/pandas/core/indexing.py in _getitem_axis(self, key, axis)
#    1097                     raise ValueError("Cannot index with multidimensional key")
#    1098
# -> 1099                 return self._getitem_iterable(key, axis=axis)
#    1100
#    1101             # nested tuple slicing
#
# ~/.local/lib/python3.6/site-packages/pandas/core/indexing.py in _getitem_iterable(self, key, axis)
#    1035
# ...

# %%
df.head()
# Out:
#     order_id  order_date    status   item_id                  sku  \
# 0  100354678  2020-10-01  received  574772.0   oasis_Oasis-064-36
# 1  100354678  2020-10-01  received  574774.0      Fantastic_FT-48
# 2  100354680  2020-10-01  complete  574777.0      mdeal_DMC-610-8
# 3  100354680  2020-10-01  complete  574779.0   oasis_Oasis-061-36
# 4  100367357  2020-11-13  received  595185.0  MEFNAR59C38B6CA08CD
#
#    qty_ordered  price   value  discount_amount   total  ...          SSN  \
# 0         21.0   89.9  1798.0              0.0  1798.0  ...  627-31-5251
# 1         11.0   19.0   190.0              0.0   190.0  ...  627-31-5251
# 2          9.0  149.9  1199.2              0.0  1199.2  ...  627-31-5251
# 3          9.0   79.9   639.2              0.0   639.2  ...  627-31-5251
# 4          2.0   99.9    99.9              0.0    99.9  ...  627-31-5251
#
#      Phone No.  Place Name  County    City State    Zip Region User Name  \
# ...

# %%
df["price"] > 100
df2 = df.loc[df['price'] > 100,["status"]]

# %% [markdown]
# df2

# %%
df2
# Out:
#                 status
# 2             complete
# 8             canceled
# 9             canceled
# 10      order_refunded
# 11      order_refunded
# ...                ...
# 286384        canceled
# 286385        canceled
# 286386      processing
# 286387            paid
# 286391      processing
#
# [150296 rows x 1 columns]

# %%
df["price"] > 100
df2 = df.loc[df['price'] > 100,["price"]]

# %%
df2
# Out:
#           price
# 2         149.9
# 8         135.0
# 9         549.9
# 10        549.9
# 11        549.9
# ...         ...
# 286384  12999.9
# 286385    104.8
# 286386    104.8
# 286387   4419.9
# 286391   3559.9
#
# [150296 rows x 1 columns]

# %%
df["price"] > 100
df2 = df.loc[df['price'] > 100,["status","City"]]

# %%
df2
# Out:
#                 status          City
# 2             complete        Vinson
# 8             canceled        Graham
# 9             canceled        Graham
# 10      order_refunded        Graham
# 11      order_refunded        Graham
# ...                ...           ...
# 286384        canceled         Bronx
# 286385        canceled  Chambersburg
# 286386      processing  Chambersburg
# 286387            paid     Rushville
# 286391      processing     Knoxville
#
# [150296 rows x 2 columns]

# %%
df[df["price"] > 100]
# Out:
#          order_id  order_date          status   item_id  \
# 2       100354680  2020-10-01        complete  574777.0
# 8       100354677  2020-10-01        canceled  574770.0
# 9       100354677  2020-10-01        canceled  574771.0
# 10      100356116  2020-10-08  order_refunded  577467.0
# 11      100358724  2020-10-21  order_refunded  581862.0
# ...           ...         ...             ...       ...
# 286384  100562362  2021-09-30        canceled  905174.0
# 286385  100562363  2021-09-30        canceled  905175.0
# 286386  100562364  2021-09-30      processing  905177.0
# 286387  100562365  2021-09-30            paid  905179.0
# 286391  100562386  2021-09-30      processing  905205.0
#
#                               sku  qty_ordered    price    value  \
# 2                 mdeal_DMC-610-8          9.0    149.9   1199.2
# 8       oasis_Kingston-32GB-DTIG4          2.0    135.0    135.0
# 9                  Geepas_GSB5420          2.0    549.9    549.9
# ...

# %%
df["price"] > 100
df2 = df.loc[df['price'] > 100,["status","City"]]

# %%
df2
# Out:
#                 status          City
# 2             complete        Vinson
# 8             canceled        Graham
# 9             canceled        Graham
# 10      order_refunded        Graham
# 11      order_refunded        Graham
# ...                ...           ...
# 286384        canceled         Bronx
# 286385        canceled  Chambersburg
# 286386      processing  Chambersburg
# 286387            paid     Rushville
# 286391      processing     Knoxville
#
# [150296 rows x 2 columns]

# %%
df3 = df[df["price"] > 100]

# %%
df3["status"]
# Out:
#          order_id  order_date          status   item_id  \
# 2       100354680  2020-10-01        complete  574777.0
# 8       100354677  2020-10-01        canceled  574770.0
# 9       100354677  2020-10-01        canceled  574771.0
# 10      100356116  2020-10-08  order_refunded  577467.0
# 11      100358724  2020-10-21  order_refunded  581862.0
# ...           ...         ...             ...       ...
# 286384  100562362  2021-09-30        canceled  905174.0
# 286385  100562363  2021-09-30        canceled  905175.0
# 286386  100562364  2021-09-30      processing  905177.0
# 286387  100562365  2021-09-30            paid  905179.0
# 286391  100562386  2021-09-30      processing  905205.0
#
#                               sku  qty_ordered    price    value  \
# 2                 mdeal_DMC-610-8          9.0    149.9   1199.2
# 8       oasis_Kingston-32GB-DTIG4          2.0    135.0    135.0
# 9                  Geepas_GSB5420          2.0    549.9    549.9
# ...

# %%
df3["status"]
# Out:
# 2               complete
# 8               canceled
# 9               canceled
# 10        order_refunded
# 11        order_refunded
#                ...
# 286384          canceled
# 286385          canceled
# 286386        processing
# 286387              paid
# 286391        processing
# Name: status, Length: 150296, dtype: object

# %%
test1 = df[df["status"].isin(["complete","canceled"])]

# %%
test1.head(n = 10)
# Out:
#      order_id  order_date    status   item_id                        sku  \
# 2   100354680  2020-10-01  complete  574777.0            mdeal_DMC-610-8
# 3   100354680  2020-10-01  complete  574779.0         oasis_Oasis-061-36
# 7   100354677  2020-10-01  canceled  574769.0         GFE_19_USBLEDLight
# 8   100354677  2020-10-01  canceled  574770.0  oasis_Kingston-32GB-DTIG4
# 9   100354677  2020-10-01  canceled  574771.0             Geepas_GSB5420
# 12  100403034  2020-12-24  canceled  656937.0        APPWES59CA4D59CB41A
# 13  100403034  2020-12-24  canceled  656938.0        APPPHI5A09939191938
# 14  100403034  2020-12-24  canceled  656939.0        HALSHO59F836EF959B9
# 15  100403077  2020-12-24  canceled  657023.0        APPWES59CA4D59CB41A
# 16  100403077  2020-12-24  canceled  657024.0        APPPHI5A09939191938
#
#     qty_ordered  price   value  discount_amount       total  ...          SSN  \
# 2           9.0  149.9  1199.2          0.00000  1199.20000  ...  627-31-5251
# ...

# %%
test1.loc[0:5, :]
# Out:
#     order_id  order_date    status   item_id                 sku  qty_ordered  \
# 2  100354680  2020-10-01  complete  574777.0     mdeal_DMC-610-8          9.0
# 3  100354680  2020-10-01  complete  574779.0  oasis_Oasis-061-36          9.0
#
#    price   value  discount_amount   total  ...          SSN    Phone No.   \
# 2  149.9  1199.2              0.0  1199.2  ...  627-31-5251  405-959-1129
# 3   79.9   639.2              0.0   639.2  ...  627-31-5251  405-959-1129
#
#   Place Name  County    City State    Zip Region User Name Discount_Percent
# 2     Vinson  Harmon  Vinson    OK  73571  South   jwtitus              0.0
# 3     Vinson  Harmon  Vinson    OK  73571  South   jwtitus              0.0
#
# [2 rows x 36 columns]

# %%
test2 = df.loc[(df["price"] > 100) & (df["City"].isin(["Vinson"]))]

# %%
test2
# Out:
#     order_id  order_date    status   item_id              sku  qty_ordered  \
# 2  100354680  2020-10-01  complete  574777.0  mdeal_DMC-610-8          9.0
#
#    price   value  discount_amount   total  ...          SSN    Phone No.   \
# 2  149.9  1199.2              0.0  1199.2  ...  627-31-5251  405-959-1129
#
#   Place Name  County    City State    Zip Region User Name Discount_Percent
# 2     Vinson  Harmon  Vinson    OK  73571  South   jwtitus              0.0
#
# [1 rows x 36 columns]

# %%
test3 = df[(df["price"] > 100) & (df["City"].isin(["Graham"]))]

# %%
test3
# Out:
#          order_id  order_date          status   item_id  \
# 8       100354677  2020-10-01        canceled  574770.0
# 9       100354677  2020-10-01        canceled  574771.0
# 10      100356116  2020-10-08  order_refunded  577467.0
# 11      100358724  2020-10-21  order_refunded  581862.0
# 12      100403034  2020-12-24        canceled  656937.0
# 13      100403034  2020-12-24        canceled  656938.0
# 15      100403077  2020-12-24        canceled  657023.0
# 16      100403077  2020-12-24        canceled  657024.0
# 18      100403411  2020-12-24        canceled  657547.0
# 19      100403411  2020-12-24        canceled  657548.0
# 21      100403502  2020-12-24        canceled  657702.0
# 22      100403502  2020-12-24        canceled  657703.0
# 24      100403536  2020-12-24        complete  657777.0
# 25      100403536  2020-12-24        complete  657778.0
# 27      100422764  2020-12-28        complete  690831.0
# 17296   100357171  2020-10-14        canceled  579319.0
# ...

# %%
test3.reset_index(inplace = True)

# %%
test3
# Out:
#      index   order_id  order_date          status   item_id  \
# 0        8  100354677  2020-10-01        canceled  574770.0
# 1        9  100354677  2020-10-01        canceled  574771.0
# 2       10  100356116  2020-10-08  order_refunded  577467.0
# 3       11  100358724  2020-10-21  order_refunded  581862.0
# 4       12  100403034  2020-12-24        canceled  656937.0
# 5       13  100403034  2020-12-24        canceled  656938.0
# 6       15  100403077  2020-12-24        canceled  657023.0
# 7       16  100403077  2020-12-24        canceled  657024.0
# 8       18  100403411  2020-12-24        canceled  657547.0
# 9       19  100403411  2020-12-24        canceled  657548.0
# 10      21  100403502  2020-12-24        canceled  657702.0
# 11      22  100403502  2020-12-24        canceled  657703.0
# 12      24  100403536  2020-12-24        complete  657777.0
# 13      25  100403536  2020-12-24        complete  657778.0
# 14      27  100422764  2020-12-28        complete  690831.0
# ...

# %%
df.head()
# Out:
#     order_id  order_date    status   item_id                  sku  \
# 0  100354678  2020-10-01  received  574772.0   oasis_Oasis-064-36
# 1  100354678  2020-10-01  received  574774.0      Fantastic_FT-48
# 2  100354680  2020-10-01  complete  574777.0      mdeal_DMC-610-8
# 3  100354680  2020-10-01  complete  574779.0   oasis_Oasis-061-36
# 4  100367357  2020-11-13  received  595185.0  MEFNAR59C38B6CA08CD
#
#    qty_ordered  price   value  discount_amount   total  ...          SSN  \
# 0         21.0   89.9  1798.0              0.0  1798.0  ...  627-31-5251
# 1         11.0   19.0   190.0              0.0   190.0  ...  627-31-5251
# 2          9.0  149.9  1199.2              0.0  1199.2  ...  627-31-5251
# 3          9.0   79.9   639.2              0.0   639.2  ...  627-31-5251
# 4          2.0   99.9    99.9              0.0    99.9  ...  627-31-5251
#
#      Phone No.  Place Name  County    City State    Zip Region User Name  \
# ...

# %%
mydf = df.loc[df["price"] < 30, ["value", "SSN", "Place Name", "County"]]

# %%
mydf
# Out:
#         value          SSN         Place Name    County
# 1       190.0  627-31-5251             Vinson    Harmon
# 104      29.9  756-12-4481       Mill Springs     Wayne
# 106      29.9  200-84-5318            Phoenix  Maricopa
# 107      28.8  200-84-5318            Phoenix  Maricopa
# 109      26.0  200-84-5318            Phoenix  Maricopa
# ...       ...          ...                ...       ...
# 286353   29.9  549-99-1515  Hasbrouck Heights    Bergen
# 286354    9.8  549-99-1515  Hasbrouck Heights    Bergen
# 286355   24.5  549-99-1515  Hasbrouck Heights    Bergen
# 286356   15.0  549-99-1515  Hasbrouck Heights    Bergen
# 286366   23.5  494-29-4236              Crewe  Nottoway
#
# [44225 rows x 4 columns]

# %%
mydf
# Out:
#         value          SSN         Place Name    County
# 1       190.0  627-31-5251             Vinson    Harmon
# 104      29.9  756-12-4481       Mill Springs     Wayne
# 106      29.9  200-84-5318            Phoenix  Maricopa
# 107      28.8  200-84-5318            Phoenix  Maricopa
# 109      26.0  200-84-5318            Phoenix  Maricopa
# ...       ...          ...                ...       ...
# 286353   29.9  549-99-1515  Hasbrouck Heights    Bergen
# 286354    9.8  549-99-1515  Hasbrouck Heights    Bergen
# 286355   24.5  549-99-1515  Hasbrouck Heights    Bergen
# 286356   15.0  549-99-1515  Hasbrouck Heights    Bergen
# 286366   23.5  494-29-4236              Crewe  Nottoway
#
# [44225 rows x 4 columns]

# %%
import numpy as np

# %%
mydf["Year"] = np.array(2000)

# %%
mydf
# Out:
#         value          SSN         Place Name    County  Year
# 1       190.0  627-31-5251             Vinson    Harmon  2000
# 104      29.9  756-12-4481       Mill Springs     Wayne  2000
# 106      29.9  200-84-5318            Phoenix  Maricopa  2000
# 107      28.8  200-84-5318            Phoenix  Maricopa  2000
# 109      26.0  200-84-5318            Phoenix  Maricopa  2000
# ...       ...          ...                ...       ...   ...
# 286353   29.9  549-99-1515  Hasbrouck Heights    Bergen  2000
# 286354    9.8  549-99-1515  Hasbrouck Heights    Bergen  2000
# 286355   24.5  549-99-1515  Hasbrouck Heights    Bergen  2000
# 286356   15.0  549-99-1515  Hasbrouck Heights    Bergen  2000
# 286366   23.5  494-29-4236              Crewe  Nottoway  2000
#
# [44225 rows x 5 columns]

# %%
df.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-c42a15b2c7cf> in <module>
# ----> 1 df.head()
#
# NameError: name 'df' is not defined

# %%
df
# Out:
#          order_id  order_date      status   item_id                    sku  \
# 0       100354678  2020-10-01    received  574772.0     oasis_Oasis-064-36
# 1       100354678  2020-10-01    received  574774.0        Fantastic_FT-48
# 2       100354680  2020-10-01    complete  574777.0        mdeal_DMC-610-8
# 3       100354680  2020-10-01    complete  574779.0     oasis_Oasis-061-36
# 4       100367357  2020-11-13    received  595185.0    MEFNAR59C38B6CA08CD
# ...           ...         ...         ...       ...                    ...
# 286387  100562365  2021-09-30        paid  905179.0    APPCHA5AF14939B8F8A
# 286388  100562376  2021-09-30         cod  905191.0    MEFCOT5A8D1E973B886
# 286389  100562383  2021-09-30         cod  905200.0  WOFVAL59D5EA84167F9-M
# 286390  100562384  2021-09-30         cod  905202.0  WOFNIG5B4D7EB0E9FDD-L
# 286391  100562386  2021-09-30  processing  905205.0    MATHUA5AF70A7D1E50A
#
#         qty_ordered   price   value  discount_amount   total  ...  \
# ...

# %%
df.head()
# Out:
#     order_id  order_date    status   item_id                  sku  \
# 0  100354678  2020-10-01  received  574772.0   oasis_Oasis-064-36
# 1  100354678  2020-10-01  received  574774.0      Fantastic_FT-48
# 2  100354680  2020-10-01  complete  574777.0      mdeal_DMC-610-8
# 3  100354680  2020-10-01  complete  574779.0   oasis_Oasis-061-36
# 4  100367357  2020-11-13  received  595185.0  MEFNAR59C38B6CA08CD
#
#    qty_ordered  price   value  discount_amount   total  ...          SSN  \
# 0         21.0   89.9  1798.0              0.0  1798.0  ...  627-31-5251
# 1         11.0   19.0   190.0              0.0   190.0  ...  627-31-5251
# 2          9.0  149.9  1199.2              0.0  1199.2  ...  627-31-5251
# 3          9.0   79.9   639.2              0.0   639.2  ...  627-31-5251
# 4          2.0   99.9    99.9              0.0    99.9  ...  627-31-5251
#
#      Phone No.  Place Name  County    City State    Zip Region User Name  \
# ...

# %%
df.columns
# Out:
# Index(['order_id', 'order_date', 'status', 'item_id', 'sku', 'qty_ordered',
#        'price', 'value', 'discount_amount', 'total', 'category',
#        'payment_method', 'bi_st', 'cust_id', 'year', 'month', 'ref_num',
#        'Name Prefix', 'First Name', 'Middle Initial', 'Last Name', 'Gender',
#        'age', 'full_name', 'E Mail', 'Customer Since', 'SSN', 'Phone No. ',
#        'Place Name', 'County', 'City', 'State', 'Zip', 'Region', 'User Name',
#        'Discount_Percent'],
#       dtype='object')

# %%
df.groupby("status").mean()
# Out:
#                       item_id  qty_ordered        price        value  \
# status
# canceled        750570.169739     2.924237  1227.209571  1254.455559
# closed          740168.931818     2.136364   697.580966   633.710511
# cod             744923.751315     2.294984    95.500622   105.780070
# complete        702342.567665     2.819969   747.338311   812.127430
# holded          904208.000000     3.600000  4375.416000  4459.912000
# order_refunded  724209.265391     2.524054   695.692652   601.572920
# paid            817671.059524     5.592593   236.846776   329.257602
# payment_review  903927.947368     7.526316   182.001754   383.685965
# pending         805338.583333     2.354167  2077.643750  2332.093750
# pending_paypal  588670.500000     2.000000    73.225000    73.225000
# processing      903440.272727     2.060606  1352.247576  2305.768788
# received        798117.290468     3.711907   392.122372   448.402106
# ...
